# %% [markdown]
# # MAX-CUT for QAOA
# ***
# ## Undirected Unweighted MAX-CUT:
# ***
# The toolkit provides predefined examples for users so that the entire process of QAOA can be conducted easily within 2 functions. In the first example, we will look at undirected and unweighted; for all edges $e, w_e = 1$ and the hamiltonian can be expressed as  $H_f = \frac{1}{2}(I - \sigma^z_u \sigma^z_v)$, which also the same as our predefined objective function : ~$x_u$ & $x_v$ | $x_u$ & ~$x_v$ We just have to import the max_cut package from the predefined examples folder:

# %%
# import the predefined library
import os 
os.path.abspath(os.curdir)
os.path.sys.path.append('../predefined_problems/')

import max_cut as mc

# %% [markdown]
#  For MAX-CUT, we have to generate a graph, in this case a butterfly graph would suffice:

# %%
# Create a graph for the problem its is also adviseable to instantiate the weight of the graphs else it 
# be defaulted to 1
import networkx as nx 
import numpy as np
import matplotlib.pyplot as plt 
from   matplotlib import cm
from   matplotlib.ticker import LinearLocator, FormatStrFormatter

n     = 5
V     = np.arange(0,n,1)
E     =[(0,1,1.0),(0,2,1.0),(1,2,1.0),(3,2,1.0),(3,4,1.0),(4,2,1.0)] 

G     = nx.Graph()
G.add_nodes_from(V)
G.add_weighted_edges_from(E)

fig = plt.figure()
ax1 = plt.subplot2grid((1, 1), (0, 0))
labels = nx.get_edge_attributes(G,'weight')

nx.draw(G,with_labels=True, pos=nx.circular_layout(G), node_color='y', edge_color='g')
nx.draw_networkx_edge_labels(G,nx.circular_layout(G),edge_labels=labels)
# Out:
# /home/anand/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# {(0, 1): Text(0.654508480212244, 0.4755283023511464, '1.0'),
#  (0, 2): Text(0.09549145273252935, 0.2938926212887637, '1.0'),
#  (1, 2): Text(-0.2500000670552266, 0.7694208997980517, '1.0'),
#  (2, 3): Text(-0.8090170349302954, -6.55651103964594e-08, '1.0'),
#  (2, 4): Text(-0.24999999254941926, -0.18163562741820138, '1.0'),
#  (3, 4): Text(-0.24999993294477343, -0.7694209117189807, '1.0')}

# %% [markdown]
# The next step is to instantiate the max_cut object. For the max-cut problem; we defined the objective function $f(x)$ = $x_1 \oplus x_2$ = $\neg x_1 \wedge x_2$ | $\neg x_2 \wedge x_1$

# %%
# instantiate a MAX_CUT object which prepares converts the objective function into a pauli hamiltonian
max_cut = mc.max_cut(2,G)

# %% [markdown]
# The user also have an option of generating the quantum circuit to view the circuit layout, Users also have to delcare hyperparameters:

# %%
# Generate the circuit for graph per Edge mapping
hyperparams = [0.0,0.0,0.0,0.0]
max_cut.generate_quantumCircuit(G, hyperparams)

# %% [markdown]
# After generation of the circuit, users can run the ciruit once using **run_circuit()** to get the expectation values using Scipy's optimization algorithms to reduce the expectation value, this function was created so that users can run the circuit once after getting the optimal hyperparameters:

# %%
# run the circuit once 
results = max_cut.run_circuit()
# Out:
# backend setup: Complete running circuit
# Simulation: Complete!
# Expectation Value : 2.990234375

# %% [markdown]
# User can call **run_QAOA()** function to run  the entire process of QAOA algorithm to obtain the highest expectation value of the problem graph. The function uses scipy.opt to optimize the hyperparameters, thus, users can choose their preferred optimizer:

# %%
hyperparams=[2.44209724, 0.5108678 , 0.61853918, 0.05359925]
opt_hyperparams = max_cut.run_QAOA(hyperparams,'COBYLA')
# Out:
#      fun: -3.91796875
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 34
#   status: 1
#  success: True
#        x: array([2.46358297, 0.49638047, 0.61610792, 0.06489128])

# %%
max_cut.generate_quantumCircuit(G, opt_hyperparams)
res = max_cut.run_circuit()
# Out:
# backend setup: Complete running circuit
# Simulation: Complete!
# Expectation Value : 3.90234375

# %%
from qiskit.visualization import plot_histogram
plot_histogram(res.get_counts(),bar_labels = False)

# %% [markdown]
# ## Weighted Undirected MAX-CUT:
# ***
# The **max_cut** package also allows for weighted edges to included into the graph. The Objective function remains the same as the previous example. So we can use the same graph but this time with weights and repeat the same process:

# %%
n     = 5
V     = np.arange(0,n,1)
E     =[(0,1,6.0),(0,2,7.0),(1,2,8.0),(3,2,9.0),(3,4,10.0),(4,2,4.0)] 

G     = nx.Graph()
G.add_nodes_from(V)
G.add_weighted_edges_from(E)


labels = nx.get_edge_attributes(G,'weight')

fig = plt.figure()
ax1 = plt.subplot2grid((1, 1), (0, 0))
labels = nx.get_edge_attributes(G,'weight')

nx.draw(G,with_labels=True, pos=nx.circular_layout(G), node_color='y', edge_color='g')
nx.draw_networkx_edge_labels(G,nx.circular_layout(G),edge_labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d44ade539ae4> in <module>
#       1 n     = 5
# ----> 2 V     = np.arange(0,n,1)
#       3 E     =[(0,1,6.0),(0,2,7.0),(1,2,8.0),(3,2,9.0),(3,4,10.0),(4,2,4.0)]
#       4
#       5 G     = nx.Graph()
#
# NameError: name 'np' is not defined

# %%
# instantiate a MAX_CUT object which prepares converts the objective function into a Pauli Hamiltonian
shots = 1024
hyperparams=[2.16149434, 2.28535718, 1.64643326, 1.21452401, 2.3402498 ,
       1.43574739, 0.78748841, 1.62426252, 2.219211  , 2.18111064,
       0.62319434, 1.1945989 , 2.28503689, 1.42890935, 1.79117403,
       1.51900926, 2.17752931, 2.22967806, 0.66207637, 1.2113105 ]
max_cutWeights = mc.max_cut(10, G, shots=shots)
max_cutWeights.generate_quantumCircuit(G, hyperparams)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4349d0ee2a73> in <module>
#       8        2.23523146, 0.66348315, 1.210772  , 2.31522948, 1.41947488,
#       9        0.78835772, 1.64721835]
# ---> 10 max_cutWeights = mc.max_cut(16, G, shots=shots)
#      11 max_cutWeights.generate_quantumCircuit(G, hyperparams)
#
# NameError: name 'G' is not defined

# %% [markdown]
# The process is entirely the same as the examples without weights:

# %%
opt_hyperparams = max_cutWeights.run_QAOA(hyperparams,'COBYLA')
# Out:
#      fun: -28.7490234375
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 229
#   status: 1
#  success: True
#        x: array([2.14659107, 2.29024988, 1.73530987, 1.13341894, 2.33513265,
#        1.4335164 , 0.78778073, 1.67436877, 2.10419877, 2.31786933,
#        0.61631627, 1.20033502, 2.29742562, 1.40474882, 1.8100699 ,
#        1.50073342, 2.17860135, 2.2243833 , 0.68857017, 1.21772402,
#        2.34393745, 1.42444417, 0.78503484, 1.49562685, 2.18264358,
#        2.23248763, 0.65630538, 1.20073826, 2.3110564 , 1.45015289,
#        0.80429301, 1.64802965])

# %%
max_cutWeights.generate_quantumCircuit(G, opt_hyperparams)
res = max_cutWeights.run_circuit()
# Out:
# backend setup: Complete running circuit
# Simulation: Complete!
# Expectation Value : 28.822265625

# %%
from qiskit.visualization import plot_histogram
plot_histogram(res.get_counts(),figsize = (30,20),bar_labels = False)

# %% [markdown]
# ## Directed Weighted MAX-CUT:
#
#  The Objective function for directed MAX-CUT is defined as  $\neg x_u $ & $ x_v$ , meaning only edges leaving the set of vertices in set "0" -> "1" are included into the expectation value. However the user only need to specify that the edges are directed when instantiating the max_cut object by setting _directed_= True:

# %%
G = nx.DiGraph()
n     = 5
V     = np.arange(0,n,1)
E     =[(0,1,6.0),(2,0,7.0),(1,2,8.0),(3,2,9.0),(3,4,10.0),(4,2,4.0)] 

G.add_nodes_from(V)
G.add_weighted_edges_from(E)

fig = plt.figure()
ax1 = plt.subplot2grid((1, 1), (0, 0))
labels = nx.get_edge_attributes(G,'weight')

nx.draw(G,with_labels=True, pos=nx.circular_layout(G), node_color='y', edge_color='g')
nx.draw_networkx_edge_labels(G,nx.circular_layout(G),edge_labels=labels)
# Out:
# /home/anand/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# {(0, 1): Text(0.654508480212244, 0.4755283023511464, '6.0'),
#  (1, 2): Text(-0.2500000670552266, 0.7694208997980517, '8.0'),
#  (2, 0): Text(0.09549145273252935, 0.2938926212887637, '7.0'),
#  (3, 2): Text(-0.8090170349302954, -6.55651103964594e-08, '9.0'),
#  (3, 4): Text(-0.24999993294477343, -0.7694209117189807, '10.0'),
#  (4, 2): Text(-0.24999999254941926, -0.18163562741820138, '4.0')}

# %% [markdown]
# Since the objective function is  $\neg x_u $ & $ x_v$ ,the expression expands out with single pauli $Z$ gates and pauli $ZZ$ expressions:
#
# **QUESTION**:
# 1. Do single pauli z need to be included in the expression?
# 2. Do the single pauli z need a sperate set of hyperparameters?

# %%
# instantiate a MAX_CUT object which prepares converts the objective function into a pauli hamiltonian
shots = 1024
hyperparams =[3.36568612, 2.89353376, 1.94995502, 2.81066211, 4.35598113,
       1.59481398, 0.37270972, 3.29721868, 2.10966901, 0.55292235,
       0.91366317, 2.55784585, 4.33938495, 0.97758835, 2.90043658,
       1.61500745, 2.23725913, 3.24234063, 0.80018804, 2.99461698]
max_cutWeights = mc.max_cut(10, G, shots=shots, directed=True)
max_cutWeights.generate_quantumCircuit(G, hyperparams)

# %%
opt_hyperparams = max_cutWeights.run_QAOA(hyperparams,'COBYLA')
# Out:
#      fun: -19.5205078125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 249
#   status: 1
#  success: True
#        x: array([3.32705679, 2.99215097, 1.94104432, 2.91082071, 4.29610743,
#        1.73249503, 0.5733062 , 3.28588338, 2.10280773, 0.56067364,
#        0.91033043, 2.5480812 , 4.29738601, 0.98102563, 2.86734805,
#        1.60621095, 2.22642578, 3.31383131, 0.67363243, 2.95371898,
#        1.42225546, 2.63525322, 3.51419577, 0.63626597, 2.86164375,
#        1.43281351, 0.38526412, 3.12556048, 3.17557568, 0.50384867,
#        1.7016748 , 2.29727367])

# %%
max_cutWeights.generate_quantumCircuit(G, opt_hyperparams)
res = max_cutWeights.run_circuit()
# Out:
# backend setup: Complete running circuit
# Simulation: Complete!
# Expectation Value : 19.4130859375

# %%
from qiskit.visualization import plot_histogram
plot_histogram(res.get_counts(),figsize = (30,20),bar_labels = False)

# %% [markdown]
# The MAX-CUT has more than enough examples online, and the next part will be on the issues with **Controlled Hamiltonians** >>>

# %%
import skeletor as sk
import numpy as np

obj1 = '5*x_1 + 10*x_2 - 7*x_3*x_4 - 20*x_1*x_2 + 30*x_4*x_1 '
v1 = ['x_1', 'x_2', 'x_3', 'x_4']

hamiltonian = sk.skeletor(8, obj1, v1, False)

hamiltonian.get_objFun()
# Out:
# -20*x_1*x_2 + 30*x_1*x_4 + 5*x_1 + 10*x_2 - 7*x_3*x_4

# %%
hamiltonian.get_pHamil()
# Out:
# -5.0*Z_1*Z_2 + 7.5*Z_1*Z_4 - 5.0*Z_1 - 1.75*Z_3*Z_4 + 1.75*Z_3 - 5.75*Z_4

# %%
hyperparams = [3.95232921, 2.33080086, 3.19833693, 1.54087435,3.95232921, 2.33080086, 3.19833693, 1.54087435,
              3.95232921, 2.33080086, 3.19833693, 1.54087435,3.95232921, 2.33080086, 3.19833693, 1.54087435]
hamiltonian.generate_quantumCircuit(hyperparams=hyperparams)

# %%
opt_param = hamiltonian.run_QAOA(hyperparams,'COBYLA')
# Out:
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# -7
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# 25
# 3
# 18
# 5
# 10
# 35
# 28
# 0
# -5
# 10
# 0
# -7
# -5
# 5
# 0
# 10
# 5
# 10
# 35
# 28
# 0
# 25
# 10
# 0
# -7
# -5
# 3
# 5
# 0
# 18
# 10
#      fun: -0.020751953125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 141
#   status: 1
#  success: True
#        x: array([5.06668471, 3.14154587, 3.59517564, 1.83183214, 4.89267895,
#        2.13548056, 3.18298968, 1.57994863, 4.33854262, 1.91598356,
#        3.21395854, 1.62251429, 3.92033399, 2.44471484, 3.21537173,
#        1.61939954])

# %%
hamiltonian.generate_quantumCircuit(opt_param)
res = hamiltonian.run_circuit()
# Out:
# backend setup: Complete running circuit
# Simulation: Complete!
# 5
# 10
# 35
# 28
# 0
# 25
# -5
# 10
# 0
# 0
# -5
# 3
# 5
# 18
# 10
# Expectation Value : 0.0209474563598633

# %%
from qiskit.visualization import plot_histogram
plot_histogram(res.get_counts(),bar_labels = False)
